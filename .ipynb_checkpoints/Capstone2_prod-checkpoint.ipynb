# %%
#Create Spark context
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('SFBikeShareProd').getOrCreate()
# Out:
# c:\users\asus\appdata\local\programs\python\python37\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
#For Plots
import matplotlib.pyplot as plt

# %%
#Importing other packages
import pandas as pd
import datetime

#Importing Spark datatypes in order to create schema for tables
from pyspark.sql.types import *
##Importing CSV file directly using pyspark by specifying schema
trip_schema_corrected = StructType ([StructField ("id" , IntegerType(), True), StructField("duration", FloatType(), True),StructField("start_date", TimestampType(),True), StructField("start_station_name", StringType(), True), StructField("start_station_id", IntegerType(), True), StructField("end_date", TimestampType(),True), StructField("end_station_name", StringType(), True)\
									   , StructField("end_station_id", IntegerType(), True), StructField("bike_id", IntegerType(), True), StructField("subscription_type", StringType(), True), StructField("zip_code", StringType(), True)])
df_trip_2 = spark.read.load('D:/Data Sets/SF Bike Sharing Data/sf-bay-area-bike-share/trip.csv', format='csv', header='true',timestampFormat='mm/dd/yyyy hh:mm', schema=trip_schema_corrected)
df_trip_2.createOrReplaceTempView('trip_2')
df_trip_2.dtypes
df_trip_2.head(20)
# Out:
# [Row(id=4576, duration=63.0, start_date=datetime.datetime(2013, 1, 29, 14, 13), start_station_name='South Van Ness at Market', start_station_id=66, end_date=datetime.datetime(2013, 1, 29, 14, 14), end_station_name='South Van Ness at Market', end_station_id=66, bike_id=520, subscription_type='Subscriber', zip_code='94127'),
#  Row(id=4607, duration=70.0, start_date=datetime.datetime(2013, 1, 29, 14, 42), start_station_name='San Jose City Hall', start_station_id=10, end_date=datetime.datetime(2013, 1, 29, 14, 43), end_station_name='San Jose City Hall', end_station_id=10, bike_id=661, subscription_type='Subscriber', zip_code='95138'),
#  Row(id=4130, duration=71.0, start_date=datetime.datetime(2013, 1, 29, 10, 16), start_station_name='Mountain View City Hall', start_station_id=27, end_date=datetime.datetime(2013, 1, 29, 10, 17), end_station_name='Mountain View City Hall', end_station_id=27, bike_id=48, subscription_type='Subscriber', zip_code='97214'),
#  Row(id=4251, duration=77.0, start_date=datetime.datetime(2013, 1, 29, 11, 29), start_station_name='San Jose City Hall', start_station_id=10, end_date=datetime.datetime(2013, 1, 29, 11, 30), end_station_name='San Jose City Hall', end_station_id=10, bike_id=26, subscription_type='Subscriber', zip_code='95060'),
#  Row(id=4299, duration=83.0, start_date=datetime.datetime(2013, 1, 29, 0, 2), start_station_name='South Van Ness at Market', start_station_id=66, end_date=datetime.datetime(2013, 1, 29, 0, 4), end_station_name='Market at 10th', end_station_id=67, bike_id=319, subscription_type='Subscriber', zip_code='94103'),
#  Row(id=4927, duration=103.0, start_date=datetime.datetime(2013, 1, 29, 18, 54), start_station_name='Golden Gate at Polk', start_station_id=59, end_date=datetime.datetime(2013, 1, 29, 18, 56), end_station_name='Golden Gate at Polk', end_station_id=59, bike_id=527, subscription_type='Subscriber', zip_code='94109'),
#  Row(id=4500, duration=109.0, start_date=datetime.datetime(2013, 1, 29, 13, 25), start_station_name='Santa Clara at Almaden', start_station_id=4, end_date=datetime.datetime(2013, 1, 29, 13, 27), end_station_name='Adobe on Almaden', end_station_id=5, bike_id=679, subscription_type='Subscriber', zip_code='95112'),
#  Row(id=4563, duration=111.0, start_date=datetime.datetime(2013, 1, 29, 14, 2), start_station_name='San Salvador at 1st', start_station_id=8, end_date=datetime.datetime(2013, 1, 29, 14, 4), end_station_name='San Salvador at 1st', end_station_id=8, bike_id=687, subscription_type='Subscriber', zip_code='95112'),
#  Row(id=4760, duration=113.0, start_date=datetime.datetime(2013, 1, 29, 17, 1), start_station_name='South Van Ness at Market', start_station_id=66, end_date=datetime.datetime(2013, 1, 29, 17, 3), end_station_name='South Van Ness at Market', end_station_id=66, bike_id=553, subscription_type='Subscriber', zip_code='94103'),
#  Row(id=4258, duration=114.0, start_date=datetime.datetime(2013, 1, 29, 11, 33), start_station_name='San Jose City Hall', start_station_id=10, end_date=datetime.datetime(2013, 1, 29, 11, 35), end_station_name='MLK Library', end_station_id=11, bike_id=107, subscription_type='Subscriber', zip_code='95060'),
#  Row(id=4549, duration=125.0, start_date=datetime.datetime(2013, 1, 29, 13, 52), start_station_name='Spear at Folsom', start_station_id=49, end_date=datetime.datetime(2013, 1, 29, 13, 55), end_station_name='Embarcadero at Bryant', end_station_id=54, bike_id=368, subscription_type='Subscriber', zip_code='94109'),
#  Row(id=4498, duration=126.0, start_date=datetime.datetime(2013, 1, 29, 13, 23), start_station_name='San Pedro Square', start_station_id=6, end_date=datetime.datetime(2013, 1, 29, 13, 25), end_station_name='Santa Clara at Almaden', end_station_id=4, bike_id=26, subscription_type='Subscriber', zip_code='95112'),
#  Row(id=4965, duration=129.0, start_date=datetime.datetime(2013, 1, 29, 19, 32), start_station_name='Mountain View Caltrain Station', start_station_id=28, end_date=datetime.datetime(2013, 1, 29, 19, 35), end_station_name='Mountain View Caltrain Station', end_station_id=28, bike_id=140, subscription_type='Subscriber', zip_code='94041'),
#  Row(id=4557, duration=130.0, start_date=datetime.datetime(2013, 1, 29, 13, 57), start_station_name='2nd at South Park', start_station_id=64, end_date=datetime.datetime(2013, 1, 29, 13, 59), end_station_name='2nd at South Park', end_station_id=64, bike_id=371, subscription_type='Subscriber', zip_code='94122'),
#  Row(id=4386, duration=134.0, start_date=datetime.datetime(2013, 1, 29, 0, 31), start_station_name='Clay at Battery', start_station_id=41, end_date=datetime.datetime(2013, 1, 29, 0, 33), end_station_name='Beale at Market', end_station_id=56, bike_id=503, subscription_type='Subscriber', zip_code='94109'),
#  Row(id=4749, duration=138.0, start_date=datetime.datetime(2013, 1, 29, 16, 57), start_station_name='Post at Kearney', start_station_id=47, end_date=datetime.datetime(2013, 1, 29, 16, 59), end_station_name='Post at Kearney', end_station_id=47, bike_id=408, subscription_type='Subscriber', zip_code='94117'),
#  Row(id=4242, duration=141.0, start_date=datetime.datetime(2013, 1, 29, 11, 25), start_station_name='San Jose City Hall', start_station_id=10, end_date=datetime.datetime(2013, 1, 29, 11, 27), end_station_name='San Jose City Hall', end_station_id=10, bike_id=26, subscription_type='Subscriber', zip_code='95060'),
#  Row(id=4329, duration=142.0, start_date=datetime.datetime(2013, 1, 29, 0, 11), start_station_name='Market at 10th', start_station_id=67, end_date=datetime.datetime(2013, 1, 29, 0, 14), end_station_name='Market at 10th', end_station_id=67, bike_id=319, subscription_type='Subscriber', zip_code='94103'),
#  Row(id=5097, duration=142.0, start_date=datetime.datetime(2013, 1, 29, 22, 21), start_station_name='Steuart at Market', start_station_id=74, end_date=datetime.datetime(2013, 1, 29, 22, 24), end_station_name='Harry Bridges Plaza (Ferry Building)', end_station_id=50, bike_id=564, subscription_type='Subscriber', zip_code='94115'),
#  Row(id=5084, duration=144.0, start_date=datetime.datetime(2013, 1, 29, 22, 6), start_station_name='Powell Street BART', start_station_id=39, end_date=datetime.datetime(2013, 1, 29, 22, 8), end_station_name='Market at 4th', end_station_id=76, bike_id=574, subscription_type='Subscriber', zip_code='94115')]

# %%
from pyspark.sql.functions import *
trip_schema_2 = StructType ([StructField ("id" , IntegerType(), True), StructField("duration", FloatType(), True),StructField("start_date", StringType(),True), StructField("start_station_name", StringType(), True), StructField("start_station_id", IntegerType(), True), StructField("end_date", StringType(),True), StructField("end_station_name", StringType(), True)\
									   , StructField("end_station_id", IntegerType(), True), StructField("bike_id", IntegerType(), True), StructField("subscription_type", StringType(), True), StructField("zip_code", StringType(), True)])
df_trip_3 = spark.read.load('D:/Data Sets/SF Bike Sharing Data/sf-bay-area-bike-share/trip.csv', format='csv', header='true', schema=trip_schema_2)
df_trip_3.createOrReplaceTempView('trip_3')
df_trip_3.withColumn('start_date', regexp_replace('start_date','-','/') )
df_trip_3.withColumn('end_date', regexp_replace('end_date','-','/') )
df_trip_3.withColumn('start_date', to_timestamp('start_date', 'mm/dd/yyyy hh:mm'))
df_trip_3.withColumn('end_date', to_timestamp('end_date', 'mm/dd/yyyy hh:mm'))
df_trip_3.dtypes
#df_trip_3.head(50)
# Out:
# [('id', 'int'),
#  ('duration', 'float'),
#  ('start_date', 'string'),
#  ('start_station_name', 'string'),
#  ('start_station_id', 'int'),
#  ('end_date', 'string'),
#  ('end_station_name', 'string'),
#  ('end_station_id', 'int'),
#  ('bike_id', 'int'),
#  ('subscription_type', 'string'),
#  ('zip_code', 'string')]

# %%
#Number of trips from each station
trip_count=spark.sql('select start_station_id,count(*) as row_count from trip_3 group by start_station_id order by count(*) desc')
trip_count.show(20)
pd_trip_count = trip_count.toPandas()
# Out:
# +----------------+---------+
# |start_station_id|row_count|
# +----------------+---------+
# |              70|    49092|
# |              69|    33742|
# |              50|    32934|
# |              60|    27713|
# |              55|    26089|
# |              61|    25837|
# |              74|    24838|
# |              77|    24172|
# |              65|    23724|
# |              67|    20272|
# |              76|    20165|
# |              64|    18496|
# |              39|    18378|
# |              73|    16306|
# |              62|    15940|
# |              56|    15709|
# |              54|    14811|
# |              72|    14102|
# |              51|    14054|
# |              57|    13526|
# +----------------+---------+
# only showing top 20 rows

# %%
trip_data_check=spark.sql('select start_station_id,start_date, end_station_id, end_date from trip_3')
trip_data_check.show(20)
# Out:
# +----------------+---------------+--------------+---------------+
# |start_station_id|     start_date|end_station_id|       end_date|
# +----------------+---------------+--------------+---------------+
# |              66|8/29/2013 14:13|            66|8/29/2013 14:14|
# |              10|8/29/2013 14:42|            10|8/29/2013 14:43|
# |              27|8/29/2013 10:16|            27|8/29/2013 10:17|
# |              10|8/29/2013 11:29|            10|8/29/2013 11:30|
# |              66|8/29/2013 12:02|            67|8/29/2013 12:04|
# |              59|8/29/2013 18:54|            59|8/29/2013 18:56|
# |               4|8/29/2013 13:25|             5|8/29/2013 13:27|
# |               8|8/29/2013 14:02|             8|8/29/2013 14:04|
# |              66|8/29/2013 17:01|            66|8/29/2013 17:03|
# |              10|8/29/2013 11:33|            11|8/29/2013 11:35|
# |              49|8/29/2013 13:52|            54|8/29/2013 13:55|
# |               6|8/29/2013 13:23|             4|8/29/2013 13:25|
# |              28|8/29/2013 19:32|            28|8/29/2013 19:35|
# |              64|8/29/2013 13:57|            64|8/29/2013 13:59|
# |              41|8/29/2013 12:31|            56|8/29/2013 12:33|
# |              47|8/29/2013 16:57|            47|8/29/2013 16:59|
# |              10|8/29/2013 11:25|            10|8/29/2013 11:27|
# |              67|8/29/2013 12:11|            67|8/29/2013 12:14|
# |              74|8/29/2013 22:21|            50|8/29/2013 22:24|
# |              39|8/29/2013 22:06|            76|8/29/2013 22:08|
# +----------------+---------------+--------------+---------------+
# only showing top 20 rows

# %%
pd_trip_count.count()
pd_trip_count_max = pd_trip_count.loc[pd_trip_count['row_count']>5000]
pd_trip_count_min = pd_trip_count.loc[pd_trip_count['row_count']<5000]

# %%
pd_trip_count_max.plot.bar(grid=False, x='start_station_id', y='row_count')
plt.figure(figsize=(35,35))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Number of trips from each station
subscriber_type_trips=spark.sql('select subscription_type,count(*) as trip_count from trip_3 group by subscription_type order by count(*) desc')
subscriber_type_trips.show()
pd_subscr_type_trips = subscriber_type_trips.toPandas()
# Out:
# +-----------------+----------+
# |subscription_type|trip_count|
# +-----------------+----------+
# |       Subscriber|    566746|
# |         Customer|    103213|
# +-----------------+----------+

# %%
pd_subscriber_type_trips = pd_subscr_type_trips.set_index(['subscription_type'])
print(pd_subscriber_type_trips)
pd_subscriber_type_trips.plot.pie(y='trip_count', figsize=(6,6))
plt.show()
# Out:
#                    trip_count
# subscription_type
# Subscriber             566746
# Customer               103213

# %%
##Experimental Time series - analyzing data from one station
station_70=spark.sql('select * from trip_3 where start_station_id = 70')
pd_station_70 = station_70.toPandas()

# %%
#Checking datatypes  - verifying timestamps
print(pd_station_70.dtypes)
# Out:
# id                      int32
# duration              float32
# start_date             object
# start_station_name     object
# start_station_id        int32
# end_date               object
# end_station_name       object
# end_station_id          int32
# bike_id                 int32
# subscription_type      object
# zip_code               object
# dtype: object

# %%
pd_station_70['start_date'] = pd.to_datetime(pd_station_70['start_date'])
pd_station_70['end_date'] = pd.to_datetime(pd_station_70['end_date'])

# %%
print(pd_station_70.dtypes)
# Out:
# id                             int32
# duration                     float32
# start_date            datetime64[ns]
# start_station_name            object
# start_station_id               int32
# end_date              datetime64[ns]
# end_station_name              object
# end_station_id                 int32
# bike_id                        int32
# subscription_type             object
# zip_code                      object
# dtype: object

# %%
#Setting start_date as index
pd_station_70.set_index('start_date', inplace=True)

# %%
#Checking if index is set and range of index
pd_station_70.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 49092 entries, 2013-08-29 15:48:00 to 2014-09-01 09:41:00
# Data columns (total 10 columns):
# id                    49092 non-null int32
# duration              49092 non-null float32
# start_station_name    49092 non-null object
# start_station_id      49092 non-null int32
# end_date              49092 non-null datetime64[ns]
# end_station_name      49092 non-null object
# end_station_id        49092 non-null int32
# bike_id               49092 non-null int32
# subscription_type     49092 non-null object
# zip_code              48916 non-null object
# dtypes: datetime64[ns](1), float32(1), int32(4), object(4)
# memory usage: 3.2+ MB

# %%
#Converting seconds to minutes
pd_station_70['dur_min'] = round(pd_station_70['duration']/60,1)

#General time series on duration
pd_station_70.dur_min.plot(figsize=(20,20))
plt.show()


#Duration by year
duration = pd.DataFrame()
for year in ['2013', '2014']:
    duration_per_year = pd_station_70.loc[year,['dur_min']].reset_index(drop=True)
    duration_per_year.rename(columns={'dur_min':year}, inplace=True)
    duration = pd.concat([duration,duration_per_year], axis=1)
    
#Plot time series of duration for each year
duration.plot(figsize=(20,20), subplots=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-20cd5c4996de> in <module>
#       1
#       2 #Converting seconds to minutes
# ----> 3 pd_station_70['dur_min'] = round(pd_station_70['duration']/60,1)
#       4
#       5 #General time series on duration
#
# D:\Spark_2_3\spark-2.3.2-bin-hadoop2.7\python\pyspark\sql\functions.py in round(col, scale)
#     565     """
#     566     sc = SparkContext._active_spark_context
# --> 567     return Column(sc._jvm.functions.round(_to_java_column(col), scale))
#     568
#     569
#
# D:\Spark_2_3\spark-2.3.2-bin-hadoop2.7\python\pyspark\sql\column.py in _to_java_column(col)
#      52             "{0} of type {1}. "
#      53             "For column literals, use 'lit', 'array', 'struct' or 'create_map' "
# ---> 54             "function.".format(col, type(col)))
#      55     return jcol
#      56
#
# TypeError: Invalid argument, not a string or column: start_date
# 2013-08-29 15:48:00      3.983333
# 2013-08-29 11:03:00      4.633333
# 2013-08-29 16:23:00      5.616667
# 2013-08-29 16:24:00      6.250000
# 2013-08-29 22:53:00      6.533333
# 2013-08-29 21:38:00      7.050000
# 2013-08-29 17:46:00      7.766667
# 2013-08-29 17:45:00      9.050000
# 2013-08-29 11:54:00      9.533334
# 2013-08-29 17:45:00      9.650000
# 2013-08-29 15:03:00     10.183333
# 2013-08-29 13:45:00     10.400000
# 2013-08-29 15:02:00     10.400000
# 2013-08-29 11:32:00     10.483334
# 2013-08-29 20:22:00     11.400000
# 2013-08-29 11:26:00     12.000000
# 2013-08-29 20:51:00     12.616667
# 2013-08-29 14:30:00     14.450000
# 2013-08-29 16:20:00     14.633333
# 2013-08-29 18:31:00     14.650000
# 2013-08-29 11:26:00     17.850000
# 2013-08-29 16:16:00     18.950001
# 2013-08-29 16:16:00     18.966667
# 2013-08-29 11:18:00     19.166666
# 2013-08-29 19:52:00     19.816668
# 2013-08-29 17:38:00     20.966667
# 2013-08-29 18:41:00     21.049999
# 2013-08-29 11:18:00     25.000000
# 2013-08-29 11:17:00     25.583334
# 2013-08-29 11:17:00     26.549999
#                           ...
# 2014-09-02 07:48:00     14.550000
# 2014-09-02 07:48:00      9.033334
# 2014-09-02 07:48:00     11.533334
# 2014-09-02 07:47:00     13.966666
# 2014-09-02 07:44:00      8.700000
# 2014-09-02 07:43:00      7.550000
# 2014-09-02 07:42:00     10.650000
# 2014-09-02 07:25:00     12.183333
# 2014-09-02 07:24:00      6.933333
# 2014-09-02 07:24:00      9.933333
# 2014-09-02 07:23:00      9.300000
# 2014-09-02 07:23:00      7.000000
# 2014-09-02 07:22:00     21.900000
# 2014-09-02 07:05:00     13.716666
# 2014-09-02 06:47:00     17.600000
# 2014-09-02 06:44:00      6.966667
# 2014-09-02 06:42:00     12.550000
# 2014-09-02 06:41:00      8.416667
# 2014-09-02 06:34:00      9.600000
# 2014-09-02 05:58:00      8.683333
# 2014-09-01 14:40:00     19.416666
# 2014-09-01 14:27:00      7.050000
# 2014-09-01 13:40:00    470.433319
# 2014-09-01 12:02:00     17.016666
# 2014-09-01 11:56:00     23.816668
# 2014-09-01 11:53:00     26.916666
# 2014-09-01 11:52:00     28.100000
# 2014-09-01 11:51:00     27.716667
# 2014-09-01 11:38:00     17.333334
# 2014-09-01 09:41:00     11.916667
# Name: duration, Length: 49092, dtype: float32 of type <class 'pandas.core.series.Series'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.

# %%
#reading station data
station_schema =StructType([StructField("id", IntegerType(), True), StructField("name", StringType(), True), StructField("lat", FloatType(),True), StructField("long", FloatType(), True), StructField("dock_count", IntegerType(),True),  StructField("city",StringType(), True), StructField("installation_date",DateType(), True)])
df_station = spark.read.load('D:/Data Sets/SF Bike Sharing Data/sf-bay-area-bike-share/station.csv', format='csv', header='true', schema=station_schema)
df_station.createOrReplaceTempView('station')
station_70_detailed = spark.sql('select a.id, (a.duration/60) as trip_duration, a.start_station_name, a.start_date, a.start_station_id, b.lat, b.long, a.end_date, a.end_station_id, a.bike_id, a.subscription_type, a.zip_code, b.city, b.dock_count from trip_3 a LEFT OUTER JOIN station b ON a.start_station_id = b.id WHERE a.start_station_id = 70')
station_70_detailed.collect()
station_70_detailed.createOrReplaceTempView('iter_1')

station_70_detailed_2 = spark.sql('select a.id, a.trip_duration,a.start_station_name, a.start_date, a.start_station_id, a.lat, a.long, a.end_date, a.end_station_id, b.lat as lat_end, b.long as long_end,  a.bike_id, a.subscription_type, a.zip_code, a.city, a.dock_count from iter_1 a LEFT OUTER JOIN station b ON a.end_station_id = b.id')
station_70_detailed_2.show(5)
# Out:
# +----+------------------+--------------------+---------------+----------------+---------+----------+---------------+--------------+---------+----------+-------+-----------------+--------+-------------+----------+
# |  id|     trip_duration|  start_station_name|     start_date|start_station_id|      lat|      long|       end_date|end_station_id|  lat_end|  long_end|bike_id|subscription_type|zip_code|         city|dock_count|
# +----+------------------+--------------------+---------------+----------------+---------+----------+---------------+--------------+---------+----------+-------+-----------------+--------+-------------+----------+
# |4673|3.9833333333333334|San Francisco Cal...|8/29/2013 15:48|              70|37.776615|-122.39526|8/29/2013 15:52|            65|37.771057|-122.40272|    568|       Subscriber|   94110|San Francisco|        19|
# |4177| 4.633333333333334|San Francisco Cal...|8/29/2013 11:03|              70|37.776615|-122.39526|8/29/2013 11:08|            64| 37.78226|-122.39274|    371|       Subscriber|   94117|San Francisco|        19|
# |4715| 5.616666666666666|San Francisco Cal...|8/29/2013 16:23|              70|37.776615|-122.39526|8/29/2013 16:29|            65|37.771057|-122.40272|    489|         Customer|   94109|San Francisco|        19|
# |4716|              6.25|San Francisco Cal...|8/29/2013 16:24|              70|37.776615|-122.39526|8/29/2013 16:30|            65|37.771057|-122.40272|    382|         Customer|   95118|San Francisco|        19|
# |5102| 6.533333333333333|San Francisco Cal...|8/29/2013 22:53|              70|37.776615|-122.39526|8/29/2013 23:00|            63| 37.78698|-122.39811|    348|         Customer|   37206|San Francisco|        19|
# +----+------------------+--------------------+---------------+----------------+---------+----------+---------------+--------------+---------+----------+-------+-----------------+--------+-------------+----------+
# only showing top 5 rows

# %% [markdown]
# There seems to be missing data in 2013 and 2015.
#
# Also good to know is that some durations are much much longer than the other ones. Perhaps need to classify durations.
#
# Trip durations are in seconds. Need to convert them to minutes.

# %%
pd_station_70_details = station_70_detailed_2.toPandas()

# %% [markdown]
# #### Calculating the distance between two points given latitude and longitude.

# %%
import geopy.distance

coords_1 = (37.776615, -122.39526)
coords_2 = (37.771057, -122.40272)

geopy.distance.vincenty(coords_1, coords_2).km
# Out:
# 0.9013988601177375

# %%
def calcDistance(x):
    coords_1 = (x[0], x[1])
    coords_2 = (x[2], x[3])
    return geopy.distance.vincenty(coords_1, coords_2).km

# %%
pd_station_70_details['distance'] = pd_station_70_details[['lat', 'long', 'lat_end', 'long_end']].apply(calcDistance, axis=1)

# %%
pd_station_70_details['distance']
# Out:
# 0         0.901009
# 1         0.664954
# 2         0.901009
# 3         0.901009
# 4         1.177382
# 5         0.018227
# 6         0.901009
# 7         1.524236
# 8         0.901009
# 9         1.689834
# 10        1.047788
# 11        1.373838
# 12        1.047788
# 13        1.332383
# 14        1.533237
# 15        0.000000
# 16        0.018227
# 17        2.036318
# 18        2.096554
# 19        2.068422
# 20        2.036318
# 21        0.000000
# 22        0.000000
# 23        1.533237
# 24        1.412176
# 25        1.549821
# 26        1.373838
# 27        2.096554
# 28        2.096554
# 29        2.096554
#            ...
# 49062     2.310548
# 49063     1.689834
# 49064     1.742944
# 49065     2.606223
# 49066     1.524236
# 49067     1.524236
# 49068     1.459637
# 49069     1.459637
# 49070     1.689834
# 49071     2.086080
# 49072     1.946490
# 49073     1.549821
# 49074     2.082500
# 49075     2.082500
# 49076     1.663834
# 49077     1.039472
# 49078     1.689834
# 49079     1.689834
# 49080     1.689834
# 49081     1.524236
# 49082     2.606223
# 49083     1.047788
# 49084    48.297636
# 49085     2.068422
# 49086     2.086080
# 49087     2.086080
# 49088     2.086080
# 49089     2.086080
# 49090     3.203066
# 49091     2.086080
# Name: distance, Length: 49092, dtype: float64

# %%
#setting start time as index for new dataframe
pd_station_70_details['start_date'] = pd.to_datetime(pd_station_70_details['start_date'])
pd_station_70_details['end_date'] = pd.to_datetime(pd_station_70_details['end_date'])
pd_station_70_details.set_index('start_date', inplace=True)

# %%
pd_station_70_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 49092 entries, 2013-08-29 15:48:00 to 2014-09-01 09:41:00
# Data columns (total 16 columns):
# id                    49092 non-null int32
# trip_duration         49092 non-null float64
# start_station_name    49092 non-null object
# start_station_id      49092 non-null int32
# lat                   49092 non-null float32
# long                  49092 non-null float32
# end_date              49092 non-null datetime64[ns]
# end_station_id        49092 non-null int32
# lat_end               49092 non-null float32
# long_end              49092 non-null float32
# bike_id               49092 non-null int32
# subscription_type     49092 non-null object
# zip_code              48916 non-null object
# city                  49092 non-null object
# dock_count            49092 non-null int32
# distance              49092 non-null float64
# dtypes: datetime64[ns](1), float32(4), float64(2), int32(5), object(4)
# memory usage: 4.7+ MB

# %%
pd_station_70_details.distance.plot(figsize=(20,20))
plt.show()

# %%
pd_station_70_daily_trips = pd_station_70_details.groupby(by=[pd_station_70_details.index.day, pd_station_70_details.index.month, pd_station_70_details.index.year])

# %%
pd_station_70_daily_trips.id.count().plot(figsize=(20,20))

# %%
pd_station_70_details['trip_count'] = 1
pd_station_70_daily_trips = pd_station_70_details['trip_count'].resample('m').sum()

# %%
pd_station_70_daily_trips.head()
pd_station_70_daily_trips['2015-01-01']
# Out:
# 7

# %%
pd_station_70_daily_trips.plot(figsize=(20,20))
plt.show()

# %%
station_70_all = spark.sql('select * from trip_3 where start_station_id = 70 OR end_station_id = 70')

# %%
station_70_all.createOrReplaceTempView('stat70_all')

# %%
station_70_all_details = spark.sql('select a.id, (a.duration/60) as trip_duration, a.start_station_name, a.start_date, a.start_station_id, b.lat, b.long, a.end_date, a.end_station_id, a.bike_id, a.subscription_type, a.zip_code, b.city, b.dock_count from stat70_all a LEFT OUTER JOIN station b ON a.start_station_id = b.id')
station_70_all_details.collect()
station_70_all_details.createOrReplaceTempView('iter_3')

station_70_all_details_final = spark.sql('select a.id, a.trip_duration,a.start_station_name, a.start_date, a.start_station_id, a.lat, a.long, a.end_date, a.end_station_id, b.lat as lat_end, b.long as long_end,  a.bike_id, a.subscription_type, a.zip_code, a.city, a.dock_count as start_stat_dock_count, b.dock_count as end_stat_dock_count from iter_3 a LEFT OUTER JOIN station b ON a.end_station_id = b.id')
station_70_all_details_final.show(5)
# Out:
# +----+------------------+--------------------+---------------+----------------+---------+----------+---------------+--------------+---------+----------+-------+-----------------+--------+-------------+---------------------+-------------------+
# |  id|     trip_duration|  start_station_name|     start_date|start_station_id|      lat|      long|       end_date|end_station_id|  lat_end|  long_end|bike_id|subscription_type|zip_code|         city|start_stat_dock_count|end_stat_dock_count|
# +----+------------------+--------------------+---------------+----------------+---------+----------+---------------+--------------+---------+----------+-------+-----------------+--------+-------------+---------------------+-------------------+
# |4673|3.9833333333333334|San Francisco Cal...|8/29/2013 15:48|              70|37.776615|-122.39526|8/29/2013 15:52|            65|37.771057|-122.40272|    568|       Subscriber|   94110|San Francisco|                   19|                 15|
# |5105| 4.083333333333333|     Townsend at 7th|8/29/2013 23:12|              65|37.771057|-122.40272|8/29/2013 23:16|            70|37.776615|-122.39526|    348|         Customer|   37206|San Francisco|                   15|                 19|
# |4177| 4.633333333333334|San Francisco Cal...|8/29/2013 11:03|              70|37.776615|-122.39526|8/29/2013 11:08|            64| 37.78226|-122.39274|    371|       Subscriber|   94117|San Francisco|                   19|                 15|
# |4871| 5.266666666666667|       5th at Howard|8/29/2013 18:06|              57|37.781754|-122.40513|8/29/2013 18:11|            70|37.776615|-122.39526|    348|         Customer|   94107|San Francisco|                   15|                 19|
# |4744| 5.316666666666666|       5th at Howard|8/29/2013 16:52|              57|37.781754|-122.40513|8/29/2013 16:57|            70|37.776615|-122.39526|    379|         Customer|   95032|San Francisco|                   15|                 19|
# +----+------------------+--------------------+---------------+----------------+---------+----------+---------------+--------------+---------+----------+-------+-----------------+--------+-------------+---------------------+-------------------+
# only showing top 5 rows

# %%
pd_station_70_all = station_70_all_details_final.toPandas()

# %%
pd_station_70_all['start_date'] = pd.to_datetime(pd_station_70_all['start_date'])
pd_station_70_all['end_date'] = pd.to_datetime(pd_station_70_all['end_date'])
#setting start time as index for new dataframe
pd_station_70_all.set_index('start_date', inplace=True)

# %%
pd_station_70_all = pd_station_70_all.sort_index()

# %%
pd_station_70_all.head(20)
# Out:
#                        id  trip_duration  \
# start_date
# 2013-08-29 11:03:00  4177       4.633333
# 2013-08-29 11:17:00  4218      26.550000
# 2013-08-29 11:17:00  4217      25.583333
# 2013-08-29 11:18:00  4221      25.000000
# 2013-08-29 11:18:00  4219      19.166667
# 2013-08-29 11:26:00  4244      17.850000
# 2013-08-29 11:26:00  4243      12.000000
# 2013-08-29 11:32:00  4256      10.483333
# 2013-08-29 11:54:00  4282       9.533333
# 2013-08-29 12:14:00  4346      12.066667
# 2013-08-29 13:19:00  4497      15.900000
# 2013-08-29 13:19:00  4496       6.250000
# 2013-08-29 13:39:00  4524       9.650000
# 2013-08-29 13:39:00  4525      10.833333
# 2013-08-29 13:45:00  4537      10.400000
# 2013-08-29 14:24:00  4588      29.183333
# 2013-08-29 14:25:00  4589      28.716667
# 2013-08-29 14:30:00  4593      14.450000
# 2013-08-29 15:02:00  4626      10.400000
# 2013-08-29 15:03:00  4628      10.183333
#
#                                            start_station_name  \
# start_date
# 2013-08-29 11:03:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 11:17:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 11:17:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 11:18:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 11:18:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 11:26:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 11:26:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 11:32:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 11:54:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 12:14:00                     Embarcadero at Folsom
# 2013-08-29 13:19:00      Harry Bridges Plaza (Ferry Building)
# 2013-08-29 13:19:00                           Townsend at 7th
# 2013-08-29 13:39:00                             Howard at 2nd
# 2013-08-29 13:39:00                             Howard at 2nd
# 2013-08-29 13:45:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29 14:24:00                    Embarcadero at Vallejo
# 2013-08-29 14:25:00                    Embarcadero at Vallejo
# 2013-08-29 14:30:00  San Francisco Caltrain (Townsend at 4th)
# 2013-08-29